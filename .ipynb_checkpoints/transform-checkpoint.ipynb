# %%
import pandas as pd
import numpy as np

# %%
feedback_data = pd.read_csv("feedback.csv")

feedback_data.head()
# Out:
#        Student Email            Student    Student 1 Email          Student 1  \
# 0    parth@gmail.com         Parth Shah  jessica@gmail.com  Jessica Wilkinson
# 1    elise@gmail.com           Elise Xu    parth@gmail.com         Parth Shah
# 2   joshua@gmail.com     Joshua Howland    parth@gmail.com         Parth Shah
# 3  jessica@gmail.com  Jessica Wilkinson    parth@gmail.com         Parth Shah
#
#                    Positive Feedback 1                 Negative Feedback 1  \
# 0    good feedback for jess from parth    bad feedback for jess from parth
# 1   good feedback for parth from elise   bad feedback for parth from elise
# 2  good feedback for parth from joshua  bad feedback for parth from joshua
# 3    good feedback for parth from jess    bad feedback for parth from jess
#
#     Student 2 Email       Student 2                  Positive Feedback 2  \
# 0   elise@gmail.com        Elise Xu   good feedback for elise from parth
# 1  joshua@gmail.com  Joshua Howland  good feedback for joshua from elise
# 2   elise@gmail.com        Elise Xu  good feedback for elise from joshua
# 3  joshua@gmail.com  Joshua Howland   good feedback for joshua from jess
#
#                   Negative Feedback 2    Student 3 Email          Student 3  \
# 0   bad feedback for elise from parth   joshua@gmail.com     Joshua Howland
# 1  bad feedback for joshua from elise  jessica@gmail.com  Jessica Wilkinson
# 2  bad feedback for elise from joshua  jessica@gmail.com  Jessica Wilkinson
# 3   bad feedback for joshua from jess    elise@gmail.com           Elise Xu
#
#                    Positive Feedback 3                 Negative Feedback 3
# 0  good feedback for joshua from parth  bad feedback for joshua from parth
# 1    good feedback for jess from elise    bad feedback for jess from elise
# 2   good feedback for jess from joshua   bad feedback for jess from joshua
# 3    good feedback for elise from jess    bad feedback for elise from jess

# %%
transformed_column_names = ["Student Email", "Peer 1", "Peer 1 Positive Feedback", "Peer 1 Negative Feedback", "Peer 2", "Peer 2 Positive Feedback", "Peer 2 Negative Feedback", "Peer 3", "Peer 3 Positive Feedback", "Peer 3 Negative Feedback"]

# %%
#go through each "student email column" in the feedback data
#check if there is a match to our selected student email from the transformed data
#if there is match, pull the name of the student giving feedback and their reviews
#put that in the next 3 empty feedback columns (peer name, positive feedback, negative feedback)
student_emails = feedback_data['Student Email']
student_1_emails = feedback_data['Student 1 Email']
student_2_emails = feedback_data['Student 2 Email']
student_3_emails = feedback_data['Student 3 Email']

student_count = len(transformed_data['Student Email'])
num_peers = 3
rows = []

def insert_feedback(index, peer, positive, negative):
    ##Need to complete this function
    print("Feedback for: " + student_emails[index])
    print("Feedback from: " + peer)
    print("Positive Feedback: " + positive)
    print("Negative Feedback: " + negative)
    print("\n")
    
    
    #Need to go through each column until I find an empty peer column
#     if transformed_data['Peer 1'][i]
#         print("TRUE!")
    return

for i in range(student_count):
    email = student_emails[i]
    row = [email]
    for j in range(student_count):
        if student_1_emails[j] == email:
            peer_name = feedback_data['Student'][j]
            peer_positive_feedback = feedback_data['Positive Feedback 1'][j]
            peer_negative_feedback = feedback_data['Negative Feedback 1'][j]
            insert_feedback(i, peer_name, peer_positive_feedback, peer_negative_feedback)
            row.extend([peer_name, peer_positive_feedback, peer_negative_feedback])
    for k in range(student_count):
        if student_2_emails[k] == email:
            peer_name = feedback_data['Student'][k]
            peer_positive_feedback = feedback_data['Positive Feedback 2'][k]
            peer_negative_feedback = feedback_data['Negative Feedback 2'][k]
            insert_feedback(i, peer_name, peer_positive_feedback, peer_negative_feedback)
            row.extend([peer_name, peer_positive_feedback, peer_negative_feedback])
    for m in range(student_count):
        if student_3_emails[m] == email:
            peer_name = feedback_data['Student'][m]
            peer_positive_feedback = feedback_data['Positive Feedback 3'][m]
            peer_negative_feedback = feedback_data['Negative Feedback 3'][m]
            insert_feedback(i, peer_name, peer_positive_feedback, peer_negative_feedback)
            row.extend([peer_name, peer_positive_feedback, peer_negative_feedback])
    rows.append(row)

print(rows)

df = pd.DataFrame.from_records(rows, columns=transformed_column_names)

df.head()
# Out:
# Feedback for: parth@gmail.com
# Feedback from: Elise Xu
# Positive Feedback: good feedback for parth from elise
# Negative Feedback: bad feedback for parth from elise
#
#
# Feedback for: parth@gmail.com
# Feedback from: Joshua Howland
# Positive Feedback: good feedback for parth from joshua
# Negative Feedback: bad feedback for parth from joshua
#
#
# Feedback for: parth@gmail.com
# Feedback from: Jessica Wilkinson
# Positive Feedback: good feedback for parth from jess
# Negative Feedback: bad feedback for parth from jess
#
#
# Feedback for: elise@gmail.com
# Feedback from: Parth Shah
# Positive Feedback: good feedback for elise from parth
# Negative Feedback: bad feedback for elise from parth
#
#
# Feedback for: elise@gmail.com
# Feedback from: Joshua Howland
# Positive Feedback: good feedback for elise from joshua
# Negative Feedback: bad feedback for elise from joshua
#
#
# Feedback for: elise@gmail.com
# Feedback from: Jessica Wilkinson
# Positive Feedback: good feedback for elise from jess
# Negative Feedback: bad feedback for elise from jess
#
#
# Feedback for: joshua@gmail.com
# Feedback from: Elise Xu
# Positive Feedback: good feedback for joshua from elise
# Negative Feedback: bad feedback for joshua from elise
#
#
# Feedback for: joshua@gmail.com
# Feedback from: Jessica Wilkinson
# Positive Feedback: good feedback for joshua from jess
# Negative Feedback: bad feedback for joshua from jess
#
#
# Feedback for: joshua@gmail.com
# Feedback from: Parth Shah
# Positive Feedback: good feedback for joshua from parth
# Negative Feedback: bad feedback for joshua from parth
#
#
# Feedback for: jessica@gmail.com
# Feedback from: Parth Shah
# Positive Feedback: good feedback for jess from parth
# Negative Feedback: bad feedback for jess from parth
#
#
# Feedback for: jessica@gmail.com
# Feedback from: Elise Xu
# Positive Feedback: good feedback for jess from elise
# Negative Feedback: bad feedback for jess from elise
#
#
# Feedback for: jessica@gmail.com
# Feedback from: Joshua Howland
# Positive Feedback: good feedback for jess from joshua
# Negative Feedback: bad feedback for jess from joshua
#
#
# [['parth@gmail.com', 'Elise Xu', 'good feedback for parth from elise', 'bad feedback for parth from elise', 'Joshua Howland', 'good feedback for parth from joshua', 'bad feedback for parth from joshua', 'Jessica Wilkinson', 'good feedback for parth from jess', 'bad feedback for parth from jess'], ['elise@gmail.com', 'Parth Shah', 'good feedback for elise from parth', 'bad feedback for elise from parth', 'Joshua Howland', 'good feedback for elise from joshua', 'bad feedback for elise from joshua', 'Jessica Wilkinson', 'good feedback for elise from jess', 'bad feedback for elise from jess'], ['joshua@gmail.com', 'Elise Xu', 'good feedback for joshua from elise', 'bad feedback for joshua from elise', 'Jessica Wilkinson', 'good feedback for joshua from jess', 'bad feedback for joshua from jess', 'Parth Shah', 'good feedback for joshua from parth', 'bad feedback for joshua from parth'], ['jessica@gmail.com', 'Parth Shah', 'good feedback for jess from parth', 'bad feedback for jess from parth', 'Elise Xu', 'good feedback for jess from elise', 'bad feedback for jess from elise', 'Joshua Howland', 'good feedback for jess from joshua', 'bad feedback for jess from joshua']]
#        Student Email      Peer 1             Peer 1 Positive Feedback  \
# 0    parth@gmail.com    Elise Xu   good feedback for parth from elise
# 1    elise@gmail.com  Parth Shah   good feedback for elise from parth
# 2   joshua@gmail.com    Elise Xu  good feedback for joshua from elise
# 3  jessica@gmail.com  Parth Shah    good feedback for jess from parth
#
#              Peer 1 Negative Feedback             Peer 2  \
# 0   bad feedback for parth from elise     Joshua Howland
# 1   bad feedback for elise from parth     Joshua Howland
# 2  bad feedback for joshua from elise  Jessica Wilkinson
# 3    bad feedback for jess from parth           Elise Xu
#
#               Peer 2 Positive Feedback            Peer 2 Negative Feedback  \
# 0  good feedback for parth from joshua  bad feedback for parth from joshua
# 1  good feedback for elise from joshua  bad feedback for elise from joshua
# 2   good feedback for joshua from jess   bad feedback for joshua from jess
# 3    good feedback for jess from elise    bad feedback for jess from elise
#
#               Peer 3             Peer 3 Positive Feedback  \
# 0  Jessica Wilkinson    good feedback for parth from jess
# 1  Jessica Wilkinson    good feedback for elise from jess
# 2         Parth Shah  good feedback for joshua from parth
# 3     Joshua Howland   good feedback for jess from joshua
#
#              Peer 3 Negative Feedback
# 0    bad feedback for parth from jess
# 1    bad feedback for elise from jess
# 2  bad feedback for joshua from parth
# 3   bad feedback for jess from joshua
